# %%
# import things
import matplotlib.pyplot as plt

# %matplotlib inline

x=list(range(0,10))
y=list(range(-10,0))

plt.plot(x,y)

# %%
a = (56,98,45,-90,45,-87)
b = (1,2,34,-56,-78,98)
plt.plot(a,b)

# %%
plt.axis([100,50,-50,100])
plt.plot(a,b)

# %%
plt.title("Triangle")
plt.xlabel("Array A")
plt.ylabel("Array B")
plt.axis([100,50,-50,100])
plt.xticks((100,90,80,70,60,50),('h','e','l','l','o','o'))
plt.plot(a,b, color="red")

# %%
plt.hist(a)
# Out:
# (array([2., 0., 0., 0., 0., 0., 0., 3., 0., 1.]),
#  array([-90. , -71.2, -52.4, -33.6, -14.8,   4. ,  22.8,  41.6,  60.4,
#          79.2,  98. ]),
#  <a list of 10 Patch objects>)

# %%
plt.hist(b)
# Out:
# (array([1., 1., 0., 0., 2., 0., 1., 0., 0., 1.]),
#  array([-78. , -60.4, -42.8, -25.2,  -7.6,  10. ,  27.6,  45.2,  62.8,
#          80.4,  98. ]),
#  <a list of 10 Patch objects>)

# %%
plt.hist(a)
plt.hist(b)
# Out:
# (array([1., 1., 0., 0., 2., 0., 1., 0., 0., 1.]),
#  array([-78. , -60.4, -42.8, -25.2,  -7.6,  10. ,  27.6,  45.2,  62.8,
#          80.4,  98. ]),
#  <a list of 10 Patch objects>)
